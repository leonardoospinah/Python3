# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Capitalization_and_Mutability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def capitalize_word(word):
    return "".join(char.title() for char in word)

# %%
# My solution
def capitalize_word(word):
    return word.title()

# %%
# Community solution
def capitalizeWord(word):
    return word.capitalize()

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Aspect_Ratio_Cropping_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
from typing import Tuple


def aspect_ratio(x: int, y: int) -> Tuple[int, int]:
    # 頑張って！
    pass

# %%
# My solution
from typing import Tuple
from math import ceil

def aspect_ratio(x: int, y: int) -> Tuple[int, int]:
    if y == 0:
        return x,y
    else:
        return ceil(y*(16/9)),y

# %%
# Community solution
from typing import Tuple
from math import ceil

def aspect_ratio(x: int, y: int) -> Tuple[int, int]:
    return (ceil(y * 16 / 9), y)

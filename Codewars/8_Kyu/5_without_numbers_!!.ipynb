# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/5_without_numbers_!!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![imagen_2022-01-29_160939.png](data:image/png;base64,...)

# %%
# Initial code
def unusual_five():
    return None

# %%
# My solution
def unusual_five():
    return len("five:")

# %%
# Community solution
def unusual_five():
    return len("five!")

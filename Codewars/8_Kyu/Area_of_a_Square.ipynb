# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Area_of_a_Square.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def square_area(A):
    # your code here

# %%
# My solutiion
from math import pi
def square_area(A):
    return round(A/(pi/2) * A/(pi/2),2)

# %%
# Community solution
from math import pi

def square_area(A):
    return round((2 * A / pi) ** 2, 2)

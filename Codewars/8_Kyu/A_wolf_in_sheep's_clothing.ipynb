# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/A_wolf_in_sheep's_clothing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def warn_the_sheep(queue):
    pass

# %%
# My solution
def warn_the_sheep(queue):
    for counter, x in enumerate(queue[::-1]):
        if x == "wolf" and counter > 0:
            return "Oi! Sheep number " + (str(counter)) + "! You are about to be eaten by a wolf!"
        elif x == "wolf" and counter == 0:
            return "Pls go away and stop eating my sheep"

# %%
# Community solution
def warn_the_sheep(queue):
    n = len(queue) - queue.index('wolf') - 1
    return f'Oi! Sheep number {n}! You are about to be eaten by a wolf!' if n else 'Pls go away and stop eating my sheep'

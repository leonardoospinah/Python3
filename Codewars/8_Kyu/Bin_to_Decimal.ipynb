# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Bin_to_Decimal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def bin_to_decimal(inp):
    pass

# %%
# My solution
def bin_to_decimal(inp):
    return int(inp,2)

# %%
# Community solution
def bin_to_decimal(inp):
    return int(inp, 2)

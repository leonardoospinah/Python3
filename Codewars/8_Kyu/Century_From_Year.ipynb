# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Century_From_Year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def century(year):
    # Finish this :)
    return

# %%
# My solution
from math import ceil
def century(year):
    return ceil(year*0.01)

# %%
# Community solution
from math import ceil
def century(year):
    return ceil(year*0.01)

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Basic_variable_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Inital code
a == "code"
b == "wa.rs"
name == a + b

# %%
# My solution
a = "code"
b = "wa.rs"
name = a + b

# %%
# Community solution
a = "code"
b = "wa.rs"
name = a + b

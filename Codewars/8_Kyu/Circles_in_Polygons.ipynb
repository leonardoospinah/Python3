# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Circles_in_Polygons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def circle_diameter(sides, side_length): 
    # your code here
    pass

# %%
# My solution
from math import tan, pi

def circle_diameter(sides, side_length): 
    return ((side_length)/(2*tan((180 * pi / 180)/(sides))))*2

# %%
# Community solution
import math

def circle_diameter(sides, side_length): 
    return side_length / math.tan(math.pi / sides)

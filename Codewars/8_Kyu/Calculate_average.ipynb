# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Calculate_average.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![imagen_2022-01-30_213838.png](data:image/png;base64,...)

# %%
# Initial code
def find_average(numbers):
    # your code here
    pass

# %%
# My solution
def find_average(numbers):
    return sum(numbers)/len(numbers)

# %%
# Community solution
def find_average(array):
    return sum(array) / len(array) if array else 0

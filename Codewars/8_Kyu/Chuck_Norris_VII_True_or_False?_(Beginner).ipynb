# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Chuck_Norris_VII_True_or_False%3F_(Beginner).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def if_chuck_says_so():
    # code here

# %%
# My solution
def if_chuck_says_so():
    return 1 == 2

# %%
# Community solution
def ifChuckSaysSo():
    return 0

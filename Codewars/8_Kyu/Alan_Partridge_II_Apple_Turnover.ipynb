# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Alan_Partridge_II_Apple_Turnover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def apple(x):

# %%
# My solution
def apple(x):
    if int(x) <= 31:
        return 'Help yourself to a honeycomb Yorkie for the glovebox.'
    elif int(x) <= 50:
        return "It's hotter than the sun!!"
    else:
        return "It's hotter than the sun!!"

# %%
# Community solution
def apple(x):
  return "It's hotter than the sun!!" if int(x) ** 2 > 1000 else  "Help yourself to a honeycomb Yorkie for the glovebox."

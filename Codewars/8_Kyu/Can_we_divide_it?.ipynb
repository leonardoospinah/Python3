# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Can_we_divide_it%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def is_divide_by(number, a, b):
    return # good luck

# %%
# My solution
def is_divide_by(number, a, b):
    return True if number % a == 0 and number % b == 0 else False

# %%
# Community solution
def is_divide_by(number, a, b):
    return number % a == 0 and number % b == 0

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Add_Length.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def add_length(str_):
    #your code here

# %%
# My solution
def add_length(str_):
    new_str_ = []
    for counter, x in enumerate(str_.split()):
        new_str_.append(x + " " + str(len(x)))
    return new_str_

# %%
# Community solution
def add_length(str_):
    return ["{} {}".format(i, len(i)) for i in str_.split(' ')]

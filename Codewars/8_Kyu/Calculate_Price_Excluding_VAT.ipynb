# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Calculate_Price_Excluding_VAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def excluding_vat_price(price):
    return -1

# %%
# My solution
def excluding_vat_price(price):
    return -1 if price == None else round(price/1.15,2)

# %%
# Community solution
def excludingVatPrice(price):
    return round(price / 1.15, 2) if price else -1

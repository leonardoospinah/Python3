# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/All_Star_Code_Challenge_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def str_count(strng, letter):
    # Your code here ;)

# %%
# My solution
def str_count(strng, letter):
    counter = 0
    for x in strng:
        if x == letter:
            counter += 1
    return counter

# %%
# Community solution
def strCount(string, letter):
    return string.count(letter)

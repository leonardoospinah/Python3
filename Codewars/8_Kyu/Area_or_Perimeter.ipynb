# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Area_or_Perimeter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def area_or_perimeter(l , w):
    # return your answer

# %%
# My solution
def area_or_perimeter(l , w):
    if l == w:
        return l * w
    else:
        return l * 2 + w * 2

# %%
# Community solution
def area_or_perimeter(l, w):
    return l * w if l == w else (l + w) * 2

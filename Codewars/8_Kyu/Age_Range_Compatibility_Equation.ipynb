# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Age_Range_Compatibility_Equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def dating_range(age):
    #return min-max

# %%
# My solution
def dating_range(age):
    if age <= 14:
        return str(int(age - 0.10 * age))+"-"+str(int(age + 0.10 * age))
    else:
        return str(int((age/2)+7))+"-"+str(int((age-7)*2))

# %%
# Community solution
def dating_range(age):
    if age <= 14:
        min = age - 0.10 * age
        max = age + 0.10 * age
    else:
        min = (age/2)+7
        max = (age-7)*2
        
    return str(int(min))+'-'+str(int(max))

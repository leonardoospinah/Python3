# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/A_Needle_in_the_Haystack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![imagen_2022-01-29_164015.png](data:image/png;base64,...)

# %%
# Initial code
def find_needle(haystack):
    # your code here

# %%
# My solution
def find_needle(haystack):
  counter = 0
  for x in haystack:
    if x == 'needle':
      counter += 1
      break
    else:
      counter += 1
  return "found the needle at position " + str(counter-1)

# %%
# Community solution
def find_needle(haystack): return 'found the needle at position %d' % haystack.index('needle')

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/CSV_representation_of_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def to_csv_text(array):
    pass
    # good luck

# %%
# My solution 
def to_csv_text(array):
    return '\n'.join(','.join(map(str, line)) for line in array)

# %%
# Community solution
def toCsvText(array):
    return '\n'.join(','.join(map(str, line)) for line in array)

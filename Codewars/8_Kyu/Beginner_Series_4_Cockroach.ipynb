# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Beginner_Series_4_Cockroach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def cockroach_speed(s):
    # Good Luck!

# %%
# My solution
def cockroach_speed(s):
    return int(27.778*s)

# %%
# Community solution
def cockroach_speed(s):
    return s // 0.036

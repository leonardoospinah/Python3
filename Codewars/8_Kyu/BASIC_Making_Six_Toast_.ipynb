# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/BASIC_Making_Six_Toast_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def six_toast(num):
    # you code here

# %%
# My solution
def six_toast(num):
    return abs(num - 6)

# %%
# Community solution
def six_toast(num):
  return abs(num-6)

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Classic_Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
class Solution:
    #your code here

# %%
# My solution
class Solution:
    def main (self):
        print("Hello World!")

# %%
# Community solution
class Solution:
    
    @staticmethod
    def main(self, *args):
        print("Hello World!")

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Are_there_any_arrows_left%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def any_arrows(arrows):
    print(arrows)

# %%
# My solution
def any_arrows(arrows):
    return any(not i.get("damaged", False) for i in arrows)

# %%
# Community solution
def any_arrows(arrows):
    return any(not i.get("damaged", False) for i in arrows)

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Add_new_item_(collections_are_passed_by_reference).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def add_extra(list_of_numbers):
    # your code here
    # add an int to list_of_numbers and return it

# %%
# My solution
def add_extra(list_of_numbers):
    return list_of_numbers + [1]

# %%
# Community solution
def add_extra(list_of_numbers):
    return list_of_numbers + [1]

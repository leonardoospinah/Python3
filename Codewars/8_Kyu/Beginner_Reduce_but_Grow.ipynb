# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Beginner_Reduce_but_Grow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def grow(arr):
    pass

# %%
# My solution
from math import prod

def grow(arr):
    return prod(arr)

# %%
# Community solution
from functools import reduce

def grow(arr):
    return reduce(lambda x, y: x * y, arr)

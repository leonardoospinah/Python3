# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Character_Frequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def char_freq(message):
    pass

# %%
# My solution
def char_freq(message):
    dict = {}
    for x in message:
        dict[x] = message.count(x)
    return dict

# %%
# Community solution
from collections import Counter

def char_freq(message):
    return Counter(message)

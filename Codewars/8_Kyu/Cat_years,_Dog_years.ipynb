# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Cat_years%2C_Dog_years.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def human_years_cat_years_dog_years(human_years):
    # Your code here
    return [0,0,0]

# %%
# My solution
def human_years_cat_years_dog_years(human_years):
    if human_years <= 1:
        return [1, 15, 15]
    elif human_years <=2:
        return [2, 24, 24]
    else:
        return [human_years, 16+human_years*4, 14+human_years*5]

# %%
# Community solution
def human_years_cat_years_dog_years(x):
    return [x, 24+(x-2)*4 if (x != 1) else 15, 24+(x-2)*5 if (x != 1) else 15]

# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Beginner_Series_1_School_Paperwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def paperwork(n, m):
    # Happy Coding! ^_^

# %%
# My solution
def paperwork(n, m):
    return 0 if n < 0 or m < 0 else n * m

# %%
# Community solution
def paperwork(n, m):
    return n * m if n > 0 and m > 0 else 0

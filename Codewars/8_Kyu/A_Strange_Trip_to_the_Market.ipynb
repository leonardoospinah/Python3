# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/A_Strange_Trip_to_the_Market.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![imagen_2022-01-29_165516.png](data:image/png;base64,...)

# %%
# Initial code
def is_lock_ness_monster(string):
    #your code here

# %%
# My solution
def is_lock_ness_monster(string):
    if "tree fiddy" in string:
        return True
    elif "3.50" in string:
        return True
    elif "three fifty" in string:
        return True
    else:
        return False

# %%
# Community solution
def is_lock_ness_monster(s):
    return any(i in s for i in ('tree fiddy', 'three fifty', '3.50'))

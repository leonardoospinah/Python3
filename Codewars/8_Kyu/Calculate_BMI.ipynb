# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Calculate_BMI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def bmi(weight, height):
    #your code here

# %%
# My solution
def bmi(weight, height):
    ibm = weight/height**2
    if ibm <= 18.5:
        return "Underweight"
    elif ibm <= 25.0:
        return "Normal"
    elif ibm <= 30.0:
        return "Overweight"
    else:
        return "Obese"

# %%
# Community solution
def bmi(weight, height):
    bmi = weight / height ** 2
    if bmi <= 18.5:
        return "Underweight"
    elif bmi <= 25:
        return "Normal"
    elif bmi <= 30:
        return "Overweight"
    else:
        return "Obese"

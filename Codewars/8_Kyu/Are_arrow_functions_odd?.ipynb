# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Are_arrow_functions_odd%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
odds = lambda:

# %%
# My solution
def odds (list):
    new_list = []
    for x in list:
        if x % 2 == 1:
            new_list.append(x)
    return new_list

# %%
# Community solution
def odds(values):
        return [i for i in values if i%2]

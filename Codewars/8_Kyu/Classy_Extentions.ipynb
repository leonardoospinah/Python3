# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Classy_Extentions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
class Cat(Animal):
    #your code here

# %%
# My solution
class Cat(Animal):
    def speak(self):
        return self.name + " meows."

# %%
# Community solution
class Cat(Animal):
    def speak(self):
        return self.name + ' meows.'

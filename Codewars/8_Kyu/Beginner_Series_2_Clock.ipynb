# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoospinah/Python3/blob/main/Codewars/8_Kyu/Beginner_Series_2_Clock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initial code
def past(h, m, s):
    # Good Luck!

# %%
# My solution
def past(h, m, s):
    if h == 0:
        return (m*60000) + (s*1000)
    elif m == 0:
        return (h*3600000) + (s*1000)
    elif s == 0:
        return (h*3600000) + (m*60000)
    else:
        return (h*3600000) + (m*60000) + (s*1000)

# %%
# Community solution
def past(h, m, s):
    return (3600*h + 60*m + s) * 1000
